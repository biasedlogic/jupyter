# %%
def findMissingNumber(N,TestString):
    # N kommt als Zeichenkette
    # TestString kommt als Zeichenkette 
    return int(N)

# %%
testnames = [f"{n}" for n in range(1,15)]
for testname in testnames:
    with open("tests/"+testname+".in","rt") as infile:
        N = infile.readline().strip()
        teststr = infile.readline().strip()
    with open("tests/"+testname+".out","rt") as infile:
        expected = infile.readline().strip()
    print("Count: ", N)
    if len(teststr)<40:
        print("Test string: ",teststr)
    else:
        print("Test string: ",teststr[:40],"...")
    print("Expected result: ",expected)
    result = findMissingNumber(N,teststr)
    print("Got result:",result)
    if int(expected) == int(result):
        print("Test OK\n")
    else:
        print("Test NOT OK\n")
# Out:
# Count:  2
# Test string:  2
# Expected result:  1
# Got result: 2
# Test NOT OK
#
# Count:  5
# Test string:  5 2 1 3
# Expected result:  4
# Got result: 5
# Test NOT OK
#
# Count:  10
# Test string:  2 8 10 6 5 1 3 7 4
# Expected result:  9
# Got result: 10
# Test NOT OK
#
# Count:  100
# Test string:  27 4 16 47 24 38 61 94 98 79 22 50 75 89 ...
# Expected result:  71
# Got result: 100
# Test NOT OK
#
# Count:  1000
# Test string:  180 317 772 646 705 887 914 213 177 836  ...
# Expected result:  462
# Got result: 1000
# Test NOT OK
#
# Count:  5000
# Test string:  1082 1374 1607 1868 3083 4377 1932 3971  ...
# Expected result:  1985
# Got result: 5000
# Test NOT OK
#
# Count:  10000
# Test string:  4864 1025 2485 3125 7378 6735 9514 6175  ...
# Expected result:  8954
# Got result: 10000
# Test NOT OK
#
# Count:  50000
# Test string:  25452 36669 37790 34732 14514 15795 3183 ...
# Expected result:  7626
# Got result: 50000
# Test NOT OK
#
# Count:  100000
# Test string:  53895 48538 61342 72966 60265 28151 6111 ...
# Expected result:  6727
# Got result: 100000
# Test NOT OK
#
# Count:  200000
# Test string:  36220 101447 198387 127441 182612 92671  ...
# Expected result:  180468
# Got result: 200000
# Test NOT OK
#
# Count:  200000
# Test string:  199996 199997 149999 117797 199992 19999 ...
# Expected result:  200000
# Got result: 200000
# Test OK
#
# Count:  199999
# Test string:  197381 136472 160228 128766 197225 16013 ...
# Expected result:  22690
# Got result: 199999
# Test NOT OK
#
# Count:  2
# Test string:  1
# Expected result:  2
# Got result: 2
# Test OK
#
# Count:  6
# Test string:  2 3 1 5 6
# Expected result:  4
# Got result: 6
# Test NOT OK
