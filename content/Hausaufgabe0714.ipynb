# %% [markdown]
# # Aufgabe 1: Die Zeitplanung
# Ein Wanderer möchte wissen, wie schnell wäre er an einer anderen Straßenecke, wenn er einfach quer über alles laufen könnte -- was er nicht kann, weil es ja in der Stadt auch so was außergewöhnliches wie Häuser gibt.
#
# Die Stadt, wo der Wanderer sich gerade befindet, hat einen rechteckigen Straßenplan, das heißt, es gibt nur Straßen, die Nord-Süd verlaufen und Straßen, die Ost-West verlaufen. Der Wanderer kann nur entlang den Straßen laufen.
#
# Er startet an der Kreuzung A und will zu der Kreuzung B, dafür läuft er zuerst eine Ost-West Straße "X" und dann eine Nord-Süd Straße "Y".
#
# Er zählt dabei seine Schritte entlang jeder der beiden Straßen.
#
# Schreibe ein Programm, der:
#
# 1. Fragt, wie schnell der Wanderer geht (Einheit: Schritte pro Minute)
# 2. Fragt, wie weit er entlang der Straße X gelaufen ist (Einheit: Schritte)
# 3. Fragt, wie weit er entlang der Straße Y gelaufen ist (Einheit: Schritte)
# 4. Berechnet, wie weit er gelaufen ist und wie weit der Weg wäre, wenn er direkt von A zu B laufen könnte ("quer Beet")
# 5. Berechnet, wie lange der Wanderer für seine tatsächlich gelaufene Route brauchte und wie lange er brauchen würde, könnte er direkt laufen.
#
# ## Beispiel:
#
# ```
#
# Wie schnell geht der Wanderer? [Schritte pro Minute]: 50
# Wie weit lief er die Straße X?: 3000
# Wie weit lief er die Straße Y?: 4000
# Antwort:
# Tatsächlich gelaufen: 7000 Schritte. Kürzester Weg: 5000 Schritte.
# Tatsächlich gelaufen: 140 Minuten. Kürzester Weg: 100 Minuten.
# ```
# ### Hinweis 1:
# ```
#
# from math import sqrt
# print(sqrt(4))
# ```
# ### Ergebnis:
# ```
# 2
# ```
#
# ### Hinweis 2:
#
# In einem rechtwinkligen Dreieck gilt der Pythagorassatz: a² + b² = c² wo a und b die Längen den Katheten sind und c die Länge der Hypothenuse.
#
# [https://de.wikipedia.org/wiki/Satz_des_Pythagoras]

# %%
from math import sqrt

# %% [markdown]
# # Aufgabe 2
# Gleiche Stadt. Gleiche Kreuzungen A und B. Gleiche Straßen X und Y. Die Kreuzung, wo sich die Straßen X und Y kreuzen, nennen wir mal C.
#
# Zwei Freunde laufen los, einer von der Kreuzung A und einer von der Kreuzung B los, beide laufen in Richtung Kreuzung C. Sie wollen sich dort gleichzeitig treffen und zwar nach T Sekunden. Schreibe ein Programm, der berechnet, wie schnell jeder laufen muss, so dass sich alle beide genau zu gleicher Zeit treffen.
#
# ## Beispiel
# ```
#
# Wie weit muss man von A nach C entlang der Straße X laufen? [Schritte]: 3000
# Wie weit muss man von B nach C entlang der Straße Y laufen? [Schritte]: 4000
# Nach wie vielen Sekunden wollen sich die beiden Freude treffen? [Minuten]: 50
# Antwort:
# Der, der von A nach C laufen will, soll 60 Schritte pro Minute laufen.
# Der, der von B nach C laufen will, soll 80 Schritte pro Minute laufen.
# ```
