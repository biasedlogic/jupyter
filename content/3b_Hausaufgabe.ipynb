# %%
size = int(input("Wie groß soll der Baum sein?"))
if size<1:
    print("Soll ich Dir nur die Wurzel zeichnen?! Hier ein Keimling, Größe 1:")
    size = 1
if size>10:
    print("Sorry, zu groß, wir machen max 10:")
    size = 10
for i in range(size):
    print(" "*(size-i) + "*"*(i*2+1))
print(" "*size + "|")
# Out:
# Wie groß soll der Baum sein? 7
#        *
#       ***
#      *****
#     *******
#    *********
#   ***********
#  *************
#        |

# %% [markdown]
# # Hausaufgabe
# Eine Raute in der vorgegebenen Größe zeichnen, höchstens 10.
#
# **Beispiel:** Eine Raute der Größe 5 (fünf „Etagen”) sieht so aus:
# ```
#     *
#    * *
#   *   *
#  *     *
# *       *
#  *     *
#   *   *
#    * *
#     *
# ```
# Denke daran, dass eine Zeichenkette multipliziert mit einer Zahl eine Wiederholung der Zeichenkette bedeutet!
#
# Bedenke, unter Umständen braucht man hier noch ein `if`..`else` umd die Spitzen der Raute besonders zu behandeln.
