# %%
from random import randint
w=0
würfe = [] # das ist eine leere Liste
for i in range(20):
    w = randint(1,6)
    würfe.append(w)
print(würfe)

# %%
print(würfe[3])
print(würfe[1:5])
print(würfe[10:])
print(würfe[:10])
print(würfe[-5:-2])
print(würfe[::-1])
